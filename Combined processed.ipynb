# %%
import pandas as pd

# Reading csv files 
google_store = pd.read_csv("google_store_processed.csv")
apple_store = pd.read_csv("apple_store_processed.csv")

# Combining the csv files
data = pd.concat([google_store, apple_store], ignore_index = False)

data
# Out:
#                                   Game Country  \
# 0      The Walking Dead: No Man's Land      us
# 1      The Walking Dead: No Man's Land      us
# 2      The Walking Dead: No Man's Land      us
# 3      The Walking Dead: No Man's Land      us
# 4      The Walking Dead: No Man's Land      us
# ...                                ...     ...
# 18859                       DragonVale      nl
# 18860                       DragonVale      nl
# 18861                       DragonVale      nl
# 18862                       DragonVale      nl
# 18863                       DragonVale      nl
#
#                                                   Review  Rating  \
# 0                                               Epic fun       5
# 1                                                Love it       5
# 2      All I can say is the game conceipt is pretty g...       5
# 3                                     Love this game 👍👍👍       5
# 4                                Great game endless fun.       5
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48764 entries, 0 to 18863
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Game                48764 non-null  object
#  1   Country             48764 non-null  object
#  2   Review              48764 non-null  object
#  3   Rating              48764 non-null  int64
#  4   Date                48764 non-null  object
#  5   Negative_sentiment  48764 non-null  float64
#  6   Positive_sentiment  48764 non-null  float64
#  7   Neutral_sentiment   48764 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 3.3+ MB

# %%
data = data.drop_duplicates(subset=['Review'])
data
# Out:
#                                   Game Country  \
# 0      The Walking Dead: No Man's Land      us
# 1      The Walking Dead: No Man's Land      us
# 2      The Walking Dead: No Man's Land      us
# 3      The Walking Dead: No Man's Land      us
# 4      The Walking Dead: No Man's Land      us
# ...                                ...     ...
# 18859                       DragonVale      nl
# 18860                       DragonVale      nl
# 18861                       DragonVale      nl
# 18862                       DragonVale      nl
# 18863                       DragonVale      nl
#
#                                                   Review  Rating  \
# 0                                               Epic fun       5
# 1                                                Love it       5
# 2      All I can say is the game conceipt is pretty g...       5
# 3                                     Love this game 👍👍👍       5
# 4                                Great game endless fun.       5
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19454 entries, 0 to 18863
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Game                19454 non-null  object
#  1   Country             19454 non-null  object
#  2   Review              19454 non-null  object
#  3   Rating              19454 non-null  int64
#  4   Date                19454 non-null  object
#  5   Negative_sentiment  19454 non-null  float64
#  6   Positive_sentiment  19454 non-null  float64
#  7   Neutral_sentiment   19454 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 1.3+ MB

# %%
data.to_csv('combined_review_data.csv' , index = False)

# %%
data.head(20)
# Out:
#                                Game Country  \
# 0   The Walking Dead: No Man's Land      us
# 1   The Walking Dead: No Man's Land      us
# 2   The Walking Dead: No Man's Land      us
# 3   The Walking Dead: No Man's Land      us
# 4   The Walking Dead: No Man's Land      us
# 5   The Walking Dead: No Man's Land      us
# 6   The Walking Dead: No Man's Land      us
# 7   The Walking Dead: No Man's Land      us
# 8   The Walking Dead: No Man's Land      us
# 9   The Walking Dead: No Man's Land      us
# 10  The Walking Dead: No Man's Land      us
# 11  The Walking Dead: No Man's Land      us
# 12  The Walking Dead: No Man's Land      us
# 13  The Walking Dead: No Man's Land      us
# 14  The Walking Dead: No Man's Land      us
# 15  The Walking Dead: No Man's Land      us
# 16  The Walking Dead: No Man's Land      us
# 17  The Walking Dead: No Man's Land      us
# 18  The Walking Dead: No Man's Land      us
# 19  The Walking Dead: No Man's Land      us
#
# ...
